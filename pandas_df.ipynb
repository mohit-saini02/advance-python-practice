# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
## cretae df: 

st_data = [
    [100,80,10],
    [90,70,7],
    [120,100,14],
    [80,50,2]
]
df = pd.DataFrame(st_data ,columns=['iq' , 'marks' , 'lpa'])
df
# Out:
#     iq  marks  lpa
# 0  100     80   10
# 1   90     70    7
# 2  120    100   14
# 3   80     50    2

# %%
## using dictionary: 

st_data = {
    'iq':[100,90,120,80],
    'marks':[80,70,100,50],
    'lpa':[10,7,14,2]
}

df = pd.DataFrame(st_data)
df
# Out:
#     iq  marks  lpa
# 0  100     80   10
# 1   90     70    7
# 2  120    100   14
# 3   80     50    2

# %%
## using read_csv() : 
ipl = pd.read_csv(r"C:\Users\p c\OneDrive\Desktop\dataset1\Datasets\ipl-matches.csv")

# %%
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %%
## movies data 
movies = pd.read_csv(r'C:\Users\p c\OneDrive\Desktop\dataset1\Datasets\movies.csv')

# %%
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
### series attributes :

## size 

df.size
marks.size
# Out:
# 12

# %%
## dtype : 

marks.dtype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1360\1958851589.py in ?()
#       1 ## dtype :
#       2
# ----> 3 marks.dtype
#
# c:\Users\p c\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
### head  and tail : 

## head : it shows first 5 rows of the dataset by default


ipl.head()

ipl.head(10)
# Out:
#         ID         City        Date Season  MatchNumber  \
# 0  1312200    Ahmedabad  2022-05-29   2022        Final
# 1  1312199    Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198      Kolkata  2022-05-25   2022   Eliminator
# 3  1312197      Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116       Mumbai  2022-05-22   2022           70
# 5  1304115       Mumbai  2022-05-21   2022           69
# 6  1304114       Mumbai  2022-05-20   2022           68
# 7  1304113       Mumbai  2022-05-19   2022           67
# 8  1304112  Navi Mumbai  2022-05-18   2022           66
# 9  1304111       Mumbai  2022-05-17   2022           65
#
#                          Team1                        Team2  \
# 0             Rajasthan Royals               Gujarat Titans
# 1  Royal Challengers Bangalore             Rajasthan Royals
# 2  Royal Challengers Bangalore         Lucknow Super Giants
# 3             Rajasthan Royals               Gujarat Titans
# ...

# %%
### tail : it shows the last five rows (by default ) of the dataset 
movies.tail()
# Out:
#                     title_x     imdb_id  \
# 1624  Tera Mera Saath Rahen   tt0301250
# 1625   Yeh Zindagi Ka Safar   tt0298607
# 1626        Sabse Bada Sukh   tt0069204
# 1627                  Daaka  tt10833860
# 1628               Humsafar   tt2403201
#
#                                             poster_path  \
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1626                                                NaN
# 1627  https://upload.wikimedia.org/wikipedia/en/thum...
# 1628  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                               wiki_link  \
# 1624  https://en.wikipedia.org/wiki/Tera_Mera_Saath_...
# 1625  https://en.wikipedia.org/wiki/Yeh_Zindagi_Ka_S...
# 1626      https://en.wikipedia.org/wiki/Sabse_Bada_Sukh
# 1627                https://en.wikipedia.org/wiki/Daaka
# 1628             https://en.wikipedia.org/wiki/Humsafar
#
# ...

# %%
movies.tail(10)
# Out:
#                             title_x     imdb_id  \
# 1619              Pyaar Zindagi Hai   tt0847758
# 1620       Yeh Raaste Hain Pyaar Ke   tt0292740
# 1621                        Tum Bin   tt0290326
# 1622  Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1623                       Zubeidaa   tt0255713
# 1624          Tera Mera Saath Rahen   tt0301250
# 1625           Yeh Zindagi Ka Safar   tt0298607
# 1626                Sabse Bada Sukh   tt0069204
# 1627                          Daaka  tt10833860
# 1628                       Humsafar   tt2403201
#
#                                             poster_path  \
# 1619  https://upload.wikimedia.org/wikipedia/en/5/5e...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# 1621  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1624  https://upload.wikimedia.org/wikipedia/en/2/2b...
# ...

# %%
### sample : it shows one random rows from the data by default . you can change the number of rows 

ipl.sample()
movies.sample()
# Out:
#                  title_x    imdb_id  \
# 976  Dostana (2008 film)  tt1185420
#
#                                            poster_path  \
# 976  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                              wiki_link  title_y  \
# 976  https://en.wikipedia.org/wiki/Dostana_(2008_film)  Dostana
#
#     original_title  is_adult  year_of_release runtime                genres  \
# 976        Dostana         0             2008     145  Comedy|Drama|Romance
#
#      imdb_rating  imdb_votes  \
# 976          6.5       12910
#
#                                                  story  \
# 976  After the passing of her parents  Neha Melwani...
#
#                                                summary  \
# 976  Two straight guys pretend to be gay in order t...
#
#                                     tagline  \
# 976  The party begins at a cinema near you.
#
#                                                 actors  \
# ...

# %%
# selecting coumns from dataframe : 

ipl['MatchNumber']
movies['actors']
# Out:
# 0       Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...
# 1       Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...
# 2       Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...
# 3       Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...
# 4       Mona Ambegaonkar|Ananth Narayan Mahadevan|Deva...
#                               ...
# 1624    Ajay Devgn|Sonali Bendre|Namrata Shirodkar|Pre...
# 1625    Ameesha Patel|Jimmy Sheirgill|Nafisa Ali|Gulsh...
# 1626    Vijay Arora|Asrani|Rajni Bala|Kumud Damle|Utpa...
# 1627                            Gippy Grewal|Zareen Khan|
# 1628                                          Fawad Khan|
# Name: actors, Length: 1629, dtype: object

# %%
### selecting multiple columns : 

ipl[['Season' , 'MatchNumber' , 'Team1' , 'Team2' , 'WinningTeam']]
movies[['title_x' ,'actors' , 'genres']]
# Out:
#                                    title_x  \
# 0                 Uri: The Surgical Strike
# 1                            Battalion 609
# 2     The Accidental Prime Minister (film)
# 3                          Why Cheat India
# 4                          Evening Shadows
# ...                                    ...
# 1624                 Tera Mera Saath Rahen
# 1625                  Yeh Zindagi Ka Safar
# 1626                       Sabse Bada Sukh
# 1627                                 Daaka
# 1628                              Humsafar
#
#                                                  actors            genres
# 0     Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...  Action|Drama|War
# 1     Vicky Ahuja|Shoaib Ibrahim|Shrikant Kamat|Elen...               War
# 2     Anupam Kher|Akshaye Khanna|Aahana Kumra|Atul S...   Biography|Drama
# 3     Emraan Hashmi|Shreya Dhanwanthary|Snighdadeep ...       Crime|Drama
# ...

# %%
### selecting rows from a dataset : 

st_data = {
    'name':['nitish','ankit','rupesh','rishab','amit','ankita'],
    'iq': [100,90,120,80,0,0],
    'marks':[80 , 70 , 100 , 50 , 0, 0],
    'percentage':[10,7,14,2,0,0]
}
students = pd.DataFrame(st_data)
students
# Out:
#      name   iq  marks  percentage
# 0  nitish  100     80          10
# 1   ankit   90     70           7
# 2  rupesh  120    100          14
# 3  rishab   80     50           2
# 4    amit    0      0           0
# 5  ankita    0      0           0

# %%
students.set_index('name' , inplace=True)

students
# Out:
#          iq  marks  percentage
# name
# nitish  100     80          10
# ankit    90     70           7
# rupesh  120    100          14
# rishab   80     50           2
# amit      0      0           0
# ankita    0      0           0

# %%
### iloc and loc: 
## iloc : it searches using index positions : 

## single row: 

# movies.iloc[0]
# movies[0:]

movies[0:5]
movies[0:10:2]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 2  The Accidental Prime Minister (film)  tt6986710
# 4                       Evening Shadows  tt6028796
# 6                         Fraud Saiyaan  tt5013008
# 8      Manikarnika: The Queen of Jhansi  tt6903440
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 4                                                NaN
# 6  https://upload.wikimedia.org/wikipedia/en/thum...
# 8  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
# 2  https://en.wikipedia.org/wiki/The_Accidental_P...
# 4      https://en.wikipedia.org/wiki/Evening_Shadows
# 6        https://en.wikipedia.org/wiki/Fraud_Saiyaan
# 8  https://en.wikipedia.org/wiki/Manikarnika:_The...
#
# ...

# %%
# selecting both rows and columns : 

movies.iloc[0:5 , 0:5]
movies.iloc[:10,:2]
# Out:
#                                 title_x    imdb_id
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
# 4                       Evening Shadows  tt6028796
# 5                           Soni (film)  tt6078866
# 6                         Fraud Saiyaan  tt5013008
# 7                            Bombairiya  tt4971258
# 8      Manikarnika: The Queen of Jhansi  tt6903440
# 9                      Thackeray (film)  tt7777196

# %%
### loc : it searches based on the label 

students.loc['nitish']

students.loc['nitish' :  'rishab']

students.loc['nitish':'rishab' , 'marks':'percentage']
# Out:
#         marks  percentage
# name
# nitish     80          10
# ankit      70           7
# rupesh    100          14
# rishab     50           2

# %%
### filtering a dataframe: 

ipl.head(2)
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
#
#                          Team1             Team2  \
# 0             Rajasthan Royals    Gujarat Titans
# 1  Royal Challengers Bangalore  Rajasthan Royals
#
#                               Venue        TossWinner TossDecision SuperOver  \
# 0  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals          bat         N
# 1  Narendra Modi Stadium, Ahmedabad  Rajasthan Royals        field         N
#
#         WinningTeam    WonBy  Margin method Player_of_Match  \
# 0    Gujarat Titans  Wickets     7.0    NaN       HH Pandya
# 1  Rajasthan Royals  Wickets     7.0    NaN      JC Buttler
#
#                                         Team1Players  \
# 0  ['YBK Jaiswal', 'JC Buttler', 'SV Samson', 'D ...
# 1  ['V Kohli', 'F du Plessis', 'RM Patidar', 'GJ ...
#
# ...

# %%
## Que 1. Find  all the final Winners ? 

ipl[ipl["MatchNumber"] == 'Final'][['Season','WinningTeam']]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
## Que 2. how many super over finishes have occured ? 

ipl[ipl['SuperOver'] == 'Y'].shape[0]
# Out:
# 14

# %%
## Que.3. how many matches has csk win in kolkata ? 

ipl[(ipl['City'] == 'Kolkata') & (ipl['WinningTeam'] == 'Chennai Super Kings')].shape[0]
# Out:
# 5

# %%
## Que 4. Toss Winner is the match winner in percentage ? 
round((ipl[ipl['TossWinner'] == ipl['WinningTeam']].shape[0] / ipl.shape[0]) * 100 , 2)
# Out:
# 51.47

# %%
movies.head(1)
# Out:
#                     title_x    imdb_id  \
# 0  Uri: The Surgical Strike  tt8291224
#
#                                          poster_path  \
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
#
#                                            wiki_link  \
# 0  https://en.wikipedia.org/wiki/Uri:_The_Surgica...
#
#                     title_y            original_title  is_adult  \
# 0  Uri: The Surgical Strike  Uri: The Surgical Strike         0
#
#    year_of_release runtime            genres  imdb_rating  imdb_votes  \
# 0             2019     138  Action|Drama|War          8.4       35112
#
#                                                story  \
# 0  Divided over five chapters  the film chronicle...
#
#                                              summary tagline  \
# 0  Indian army special forces execute a covert op...     NaN
#
#                                               actors wins_nominations  \
# 0  Vicky Kaushal|Paresh Rawal|Mohit Raina|Yami Ga...           4 wins
#
# ...

# %%
## Que.5. Movies with the rating higher than 8 and votes > 10000 ?

movies[(movies['imdb_rating'] > 8) & (movies['imdb_votes'] > 10000)].shape[0]
# Out:
# 43

# %%
### Action movies with rating higher than 7.5 ? 

movies[(movies['genres'].str.split('|').apply( lambda x:'Action' in x)) & (movies['imdb_rating'] > 7.5)].shape[0]
# Out:
# 33

# %%
### adding new columns : 
movies['country'] = 'India'
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
## Important Dataframe fuctions : 

## astype : used to change the datatype of a column : 

ipl["ID"].dtype
ipl['ID'] = ipl['ID'].astype('int32')
ipl["ID"].dtype
# Out:
# dtype('int32')

# %%
ipl['Season'].dtype
ipl['Season'] = ipl['Season'].astype('category')
ipl['Season'].dtype
# Out:
# CategoricalDtype(categories=['2007/08', '2009', '2009/10', '2011', '2012', '2013', '2014',
#                   '2015', '2016', '2017', '2018', '2019', '2020/21', '2021',
#                   '2022'],
# , ordered=False, categories_dtype=object)

# %%
## value_counts : use in both series and dataframe

marks = pd.DataFrame([
    [100,80,10],
    [90,70,7],
    [80,70,14],
    [80,70,14]],
    
    columns=['id','marks','package']
)

marks
# Out:
#     id  marks  package
# 0  100     80       10
# 1   90     70        7
# 2   80     70       14
# 3   80     70       14

# %%
marks.value_counts()
# Out:
# id   marks  package
# 80   70     14         2
# 90   70     7          1
# 100  80     10         1
# Name: count, dtype: int64

# %%
## Que. Find Which player has won most  player of the match in finals and qualifiers ?
ipl.head(1)
ipl[~(ipl['MatchNumber'].str.isdigit())]['Player_of_Match'].value_counts().sort_values(ascending=False).head(1)
# Out:
# Player_of_Match
# F du Plessis    3
# Name: count, dtype: int64

# %%
# plot a pie chart of Toss decision ? 

ipl['TossDecision'].value_counts().plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[237], line 4
#       1 # plot a pie chart of Toss decision ?
#       3 ipl['TossDecision'].value_counts().plot(kind='pie')
# ----> 4 plt.show()
#
# NameError: name 'plt' is not defined
